# %% [markdown]
# <a href="https://colab.research.google.com/github/ask350/Deep-Learning/blob/main/Binary_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Binary Classification - Booking cancellation data

# %%
from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ### Step 1 - Data Ingestion

# %%
import pandas as pd
url1 ="https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/booking_train.csv"
df = pd.read_csv(url1)
df.head()
# Out:
#    id  no_of_adults  no_of_children  ...  avg_price_per_room  no_of_special_requests  booking_status
# 0   0             2               0  ...               67.50                       0               0
# 1   1             2               0  ...               72.25                       0               0
# 2   2             2               0  ...               52.00                       0               0
# 3   3             1               0  ...               56.00                       0               0
# 4   4             2               0  ...              100.00                       0               1
#
# [5 rows x 19 columns]

# %% [markdown]
# ### Step 2 - Perform basic data quality check

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42100 entries, 0 to 42099
# Data columns (total 19 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   id                                    42100 non-null  int64
#  1   no_of_adults                          42100 non-null  int64
#  2   no_of_children                        42100 non-null  int64
#  3   no_of_weekend_nights                  42100 non-null  int64
#  4   no_of_week_nights                     42100 non-null  int64
#  5   type_of_meal_plan                     42100 non-null  int64
#  6   required_car_parking_space            42100 non-null  int64
#  7   room_type_reserved                    42100 non-null  int64
#  8   lead_time                             42100 non-null  int64
#  9   arrival_year                          42100 non-null  int64
#  10  arrival_month                         42100 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# id                                      0
# no_of_adults                            0
# no_of_children                          0
# no_of_weekend_nights                    0
# no_of_week_nights                       0
# type_of_meal_plan                       0
# required_car_parking_space              0
# room_type_reserved                      0
# lead_time                               0
# arrival_year                            0
# arrival_month                           0
# arrival_date                            0
# market_segment_type                     0
# repeated_guest                          0
# no_of_previous_cancellations            0
# no_of_previous_bookings_not_canceled    0
# avg_price_per_room                      0
# no_of_special_requests                  0
# booking_status                          0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Step 3 - Seperate X and Y(booking_status)

# %%
X = df.drop(columns=["id", "booking_status"])
Y = df[["booking_status"]]

# %%
X.head()
# Out:
#    no_of_adults  no_of_children  ...  avg_price_per_room  no_of_special_requests
# 0             2               0  ...               67.50                       0
# 1             2               0  ...               72.25                       0
# 2             2               0  ...               52.00                       0
# 3             1               0  ...               56.00                       0
# 4             2               0  ...              100.00                       0
#
# [5 rows x 17 columns]

# %%
Y.head()
# Out:
#    booking_status
# 0               0
# 1               0
# 2               0
# 3               0
# 4               1

# %%
Y.value_counts()
# Out:
# booking_status
# 0                 25596
# 1                 16504
# Name: count, dtype: int64

# %%
Y.value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='booking_status'>

# %% [markdown]
# ### Step 4 - Apply preprocessing on X

# %%
X.dtypes
# Out:
# no_of_adults                              int64
# no_of_children                            int64
# no_of_weekend_nights                      int64
# no_of_week_nights                         int64
# type_of_meal_plan                         int64
# required_car_parking_space                int64
# room_type_reserved                        int64
# lead_time                                 int64
# arrival_year                              int64
# arrival_month                             int64
# arrival_date                              int64
# market_segment_type                       int64
# repeated_guest                            int64
# no_of_previous_cancellations              int64
# no_of_previous_bookings_not_canceled      int64
# avg_price_per_room                      float64
# no_of_special_requests                    int64
# dtype: object

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
num_pipe = make_pipeline(
    SimpleImputer(strategy="median"),
    StandardScaler()
).set_output(transform="pandas")

# %%
X_pre = num_pipe.fit_transform(X)
X_pre.head()
# Out:
#    no_of_adults  no_of_children  ...  avg_price_per_room  no_of_special_requests
# 0      0.151040       -0.313454  ...           -0.998052               -0.737691
# 1      0.151040       -0.313454  ...           -0.870153               -0.737691
# 2      0.151040       -0.313454  ...           -1.415406               -0.737691
# 3     -1.753925       -0.313454  ...           -1.307702               -0.737691
# 4      0.151040       -0.313454  ...           -0.122955               -0.737691
#
# [5 rows x 17 columns]

# %% [markdown]
# ### Step 5 - Train-Test Split

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X_pre, Y, test_size=0.2, random_state=42)

# %%
xtrain.head()
# Out:
#        no_of_adults  no_of_children  ...  avg_price_per_room  no_of_special_requests
# 15559      0.151040       -0.313454  ...           -1.199998                1.842849
# 32783      0.151040       -0.313454  ...            0.189388                0.552579
# 11797      2.056005       -0.313454  ...            1.716096               -0.737691
# 39750      0.151040       -0.313454  ...            0.280936                0.552579
# 28711      0.151040       -0.313454  ...            0.746758               -0.737691
#
# [5 rows x 17 columns]

# %%
ytrain.head()
# Out:
#        booking_status
# 15559               0
# 32783               0
# 11797               1
# 39750               1
# 28711               1

# %%
xtest.head()
# Out:
#        no_of_adults  no_of_children  ...  avg_price_per_room  no_of_special_requests
# 8768        0.15104       -0.313454  ...           -0.643436                0.552579
# 38340       0.15104       -0.313454  ...           -0.285588               -0.737691
# 7104        0.15104       -0.313454  ...            0.002252               -0.737691
# 36898       0.15104        1.908162  ...            0.541312                3.133119
# 9747        0.15104       -0.313454  ...           -0.366636                0.552579
#
# [5 rows x 17 columns]

# %%
ytest.head()
# Out:
#        booking_status
# 8768                0
# 38340               1
# 7104                0
# 36898               0
# 9747                0

# %%
xtrain.shape
# Out:
# (33680, 17)

# %%
xtest.shape
# Out:
# (8420, 17)

# %%
xtrain.shape[1]
# Out:
# 17

# %% [markdown]
# ### as there are 17 columns we will have to set more than 17 neurons in first hidden layer

# %% [markdown]
# ### Step 6 - Build the neural network

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #### Dropout to be added after every layer to avoid overfitting

# %%
from keras.models import Sequential
from keras.layers import Input, Dense, Dropout

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Initialize the model
model = Sequential()

# Input layer
model.add(Input(shape=(xtrain.shape[1],)))

# Dense Layer 1
model.add(Dense(units=32, activation='relu'))

# Dropout Layer 1
model.add(Dropout(rate=0.3))

# Dense Layer 2
model.add(Dense(units=16, activation='relu'))

# Dropout Layer 2
model.add(Dropout(rate=0.2))

# Output Layer
model.add(Dense(units=1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 32)                  │             576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 16)                  │               0 │
# ...

# %%
model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
hist = model.fit(xtrain, ytrain, validation_split=0.2, epochs=70)
# Out:
# Epoch 1/70
# 842/842 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6648 - loss: 0.6002 - val_accuracy: 0.7720 - val_loss: 0.4831
# Epoch 2/70
# 842/842 ━━━━━━━━━━━━━━━━━━━━ 7s 2ms/step - accuracy: 0.7692 - loss: 0.4919 - val_accuracy: 0.7784 - val_loss: 0.4763
# Epoch 3/70
# 842/842 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7699 - loss: 0.4908 - val_accuracy: 0.7797 - val_loss: 0.4721
# Epoch 4/70
# 842/842 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7754 - loss: 0.4797 - val_accuracy: 0.7803 - val_loss: 0.4703
# Epoch 5/70
# 842/842 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7793 - loss: 0.4751 - val_accuracy: 0.7828 - val_loss: 0.4689
# Epoch 6/70
# 842/842 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7827 - loss: 0.4727 - val_accuracy: 0.7849 - val_loss: 0.4659
# Epoch 7/70
# 842/842 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7817 - loss: 0.4690 - val_accuracy: 0.7859 - val_loss: 0.4660
# Epoch 8/70
# ...

# %% [markdown]
# ### Plot the learning curve

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 4))
plt.plot(hist.history['loss'], label='Train Loss')
plt.plot(hist.history['val_loss'], label='Valaidation Loss')
plt.xlabel("Epochs")
plt.ylabel("Binary Cross Entropy")
plt.title("Learning Curve")
plt.legend()
plt.show()

# %% [markdown]
# ### Model evaluation

# %%
model.evaluate(xtrain, ytrain)
# Out:
# 1053/1053 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8069 - loss: 0.4293
# [0.43074876070022583, 0.8063836097717285]

# %%
model.evaluate(xtest, ytest)
# Out:
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8025 - loss: 0.4378
# [0.43539005517959595, 0.8027315735816956]

# %% [markdown]
# ### Detailed model evaluation

# %%
yprob_train = model.predict(xtrain)
yprob_train[0:5]
# Out:
# 1053/1053 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# array([[0.00712609],
#        [0.15800148],
#        [0.7956965 ],
#        [0.7674233 ],
#        [0.8035268 ]], dtype=float32)

# %% [markdown]
# ### If prob >= 0.5 classifyas 1
# ### If prob <= 0.5 classify as 0

# %%
ypred_train = [1 if prob >= 0.5 else 0 for prob in yprob_train]
ypred_train[0:5]
# Out:
# [0, 0, 1, 1, 1]

# %%
ytrain.head()
# Out:
#        booking_status
# 15559               0
# 32783               0
# 11797               1
# 39750               1
# 28711               1

# %%
yprob_test = model.predict(xtest)
yprob_test[0:5]
# Out:
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[0.04968036],
#        [0.8882677 ],
#        [0.4304176 ],
#        [0.02288846],
#        [0.2252092 ]], dtype=float32)

# %%
ypred_test = [1 if prob >= 0.5 else 0 for prob in yprob_test]
ypred_test[0:5]
# Out:
# [0, 1, 0, 0, 0]

# %%
ytest.head()
# Out:
#        booking_status
# 8768                0
# 38340               1
# 7104                0
# 36898               0
# 9747                0

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_predictions(ytest, ypred_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest, ypred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.87      0.84      5150
#            1       0.78      0.69      0.73      3270
#
#     accuracy                           0.80      8420
#    macro avg       0.80      0.78      0.79      8420
# weighted avg       0.80      0.80      0.80      8420

# %%
from sklearn.metrics import RocCurveDisplay
RocCurveDisplay.from_predictions(ytest, yprob_test)

# %% [markdown]
# ### Above model is good  and can be used for out of sample prediction

# %% [markdown]
# ### Step 8 - Out of sample prediction

# %%
url2 = "https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/refs/heads/main/booking_test.csv"
xnew = pd.read_csv(url2)
xnew.head()
# Out:
#       id  no_of_adults  ...  avg_price_per_room  no_of_special_requests
# 0  42100             3  ...              115.60                       2
# 1  42101             2  ...               85.00                       0
# 2  42102             2  ...              240.00                       1
# 3  42103             2  ...               80.75                       0
# 4  42104             1  ...              144.00                       0
#
# [5 rows x 18 columns]

# %%
xnew2 = xnew.drop(columns=["id"])
xnew2.head()
# Out:
#    no_of_adults  no_of_children  ...  avg_price_per_room  no_of_special_requests
# 0             3               0  ...              115.60                       2
# 1             2               0  ...               85.00                       0
# 2             2               2  ...              240.00                       1
# 3             2               0  ...               80.75                       0
# 4             1               0  ...              144.00                       0
#
# [5 rows x 17 columns]

# %%
num_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='median')),
#                 ('standardscaler', StandardScaler())])

# %%
xnew2_pre = num_pipe.transform(xnew2)
xnew2_pre.head()
# Out:
#    no_of_adults  no_of_children  ...  avg_price_per_room  no_of_special_requests
# 0      2.056005       -0.313454  ...            0.297092                1.842849
# 1      0.151040       -0.313454  ...           -0.526846               -0.737691
# 2      0.151040        4.129777  ...            3.646696                0.552579
# 3      0.151040       -0.313454  ...           -0.641282               -0.737691
# 4     -1.753925       -0.313454  ...            1.061793               -0.737691
#
# [5 rows x 17 columns]

# %%
probs = model.predict(xnew2_pre)
probs[0:5]
# Out:
# 878/878 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# array([[0.09678538],
#        [0.04749617],
#        [0.3742166 ],
#        [0.21249752],
#        [0.43857837]], dtype=float32)

# %%
preds = [1 if p >= 0.5 else 0 for p in probs]
preds[0:5]
# Out:
# [0, 0, 0, 0, 0]

# %%
res = xnew[["id"]]
res.head()
# Out:
#       id
# 0  42100
# 1  42101
# 2  42102
# 3  42103
# 4  42104

# %%
res["booking_pred"] = preds
res["booking_prob"] = probs
res = res.round(2)
res
# Out:
#           id  booking_pred  booking_prob
# 0      42100             0          0.10
# 1      42101             0          0.05
# 2      42102             0          0.37
# 3      42103             0          0.21
# 4      42104             0          0.44
# ...      ...           ...           ...
# 28063  70163             1          0.95
# 28064  70164             0          0.05
# 28065  70165             0          0.15
# 28066  70166             0          0.46
# 28067  70167             1          0.75
#
# [28068 rows x 3 columns]

# %%
res["booking_pred"].value_counts()
# Out:
# booking_pred
# 0    18468
# 1     9600
# Name: count, dtype: int64

# %%
res["booking_pred"].value_counts().plot(kind="barh")
# Out:
# <Axes: ylabel='booking_pred'>

# %%
res.to_csv("BookingResults.csv", index=False)

# %% [markdown]
# ### Save the model

# %%
model.save("booking.keras")

# %% [markdown]
# ### Load this model

# %%
from keras.models import load_model

# %%
nn = load_model("/content/booking.keras")
nn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 32)                  │             576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 16)                  │               0 │
# ...
